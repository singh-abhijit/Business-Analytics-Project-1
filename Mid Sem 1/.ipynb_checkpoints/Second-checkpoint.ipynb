# %%
# %matplotlib inline

import matplotlib.pyplot as pyplot;
import seaborn as sns;
import numpy as np;
import pandas as pd;

# %%
data=pd.read_csv("datasets/datafile_15.csv");

# %%
data[['Region']].apply(lambda x: len(x.unique()))
# Out:
# Region    13
# dtype: int64

# %%
print(data['Region'].unique());
# Out:
# ['NORTH AMERICA' 'CENTRAL AND SOUTH AMERICA' 'WESTERN EUROPE'
#  'EASTERN EUROPE' 'AFRICA' 'WEST ASIA' 'SOUTH ASIA' 'SOUTH EAST ASIA'
#  'EAST ASIA' 'AUSTRALASIA' 'STATELESS' 'Others' 'GRAND TOTAL']

# %%
print('before:',data.shape);
data.dropna(how='any', inplace=True);
data = data.reset_index(drop=True)
print('after:',data.shape);
# Out:
# before: (89, 17)
# after: (88, 17)

# %%
data_region=data.groupby('Region');
data_region.head();

# %%
temp_data_region=data[data['Nationality']==('Total')];
temp_data_region = temp_data_region.reset_index(drop=True)
temp_data_region
# Out:
#                        Region Nationality      2001      2002      2003  \
# 0               NORTH AMERICA       Total  417747.0  441780.0  518474.0
# 1   CENTRAL AND SOUTH AMERICA       Total   21925.0   17672.0   21654.0
# 2              WESTERN EUROPE       Total  819973.0  726783.0  847966.0
# 3              EASTERN EUROPE       Total   38863.0   40628.0   55252.0
# 4                      AFRICA       Total   90962.0   83457.0   93353.0
# 5                   WEST ASIA       Total   96424.0   92562.0  103596.0
# 6                  SOUTH ASIA       Total  672133.0  630653.0  666889.0
# 7             SOUTH EAST ASIA       Total  139975.0  149291.0  168926.0
# 8                   EAST ASIA       Total  130464.0  115424.0  150506.0
# 9                 AUSTRALASIA       Total   66104.0   63261.0   73849.0
# 10                  STATELESS       Total    9393.0   13487.0   15516.0
# 11                     Others       Total   33319.0    9366.0   10232.0
#
#          2004       2005       2006       2007       2008       2009  \
# 0    662004.0   768808.0   873306.0  1007276.0  1027297.0  1051209.0
# 1     28165.0    35586.0    38745.0    42319.0    43505.0    46604.0
# 2   1128297.0  1282119.0  1487271.0  1686083.0  1709525.0  1634042.0
# 3     82426.0   101445.0   121309.0   152764.0   191110.0   183475.0
# 4    115493.0   134801.0   142813.0   157485.0   141750.0   164474.0
# 5    122808.0   133821.0   146693.0   171661.0   215542.0   204843.0
# 6    790698.0   841969.0   908916.0   982428.0  1051846.0  1001401.0
# 7    209110.0   241408.0   281726.0   303475.0   332925.0   360191.0
# 8    201627.0   223567.0   282985.0   352037.0   355230.0   322797.0
# 9    100944.0   119778.0   137436.0   167063.0   178308.0   182451.0
# 10     1434.0    13490.0      647.0    26237.0     1025.0      624.0
# 11    13692.0    21818.0    25320.0    32676.0    34540.0    15588.0
#
#          2010       2011       2012       2013       2014       2015
# 0   1173664.0  1239705.0  1295968.0  1340531.0  1387468.0  1494930.0
# 1     62728.0    60988.0    63699.0    68436.0    69926.0    70831.0
# 2   1750342.0  1838695.0  1853066.0  1855866.0  1860580.0  1880203.0
# 3    227650.0   274598.0   312686.0   405083.0   422278.0   331051.0
# 4    204525.0   232386.0   261428.0   275271.0   280754.0   293569.0
# 5    235317.0   278773.0   290996.0   343113.0   413678.0   417616.0
# 6   1047444.0  1139659.0  1171499.0  1215035.0  1694857.0  1946207.0
# 7    439043.0   521755.0   540914.0   630054.0   685805.0   700298.0
# 8    411947.0   475951.0   535622.0   547305.0   546792.0   555770.0
# 9    210275.0   233165.0   244511.0   263574.0   286294.0   312101.0
# 10      670.0     1144.0     1426.0     1824.0     1879.0     2000.0
# 11    12087.0    12403.0     5930.0    21509.0    28788.0    22557.0

# %%
# top15_2015 = top15_2015[top15_2015.iloc[:, :84]['Nationality'] != ('Total')];
# #, top15_2015['Region'] != ('STATELESS'), top15_2015['Region'] != ('Others')
# top15_2015.drop(top15_2015.tail(1).index, inplace=True);
# top15_2015=top15_2015.reset_index(drop=True)

# %%
sns.relplot(x='temp_data_region.columns.iloc[2:]', y='temp_data_region', kind='line', data=temp_data_region, style='Region', hue='Region');
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-bfec71ddd118> in <module>
# ----> 1 sns.relplot(x='temp_data_region.columns.iloc[2:]', kind='line', data=temp_data_region, style='Region', hue='Region');
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#    1574         sizes=sizes, size_order=size_order, size_norm=size_norm,
#    1575         markers=markers, dashes=dashes, style_order=style_order,
# -> 1576         legend=legend,
#    1577     )
#    1578
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend)
#     661
#     662         plot_data = self.establish_variables(
# --> 663             x, y, hue, size, style, units, data
#     664         )
#     665
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/relational.py in establish_variables(self, x, y, hue, size, style, units, data)
#     164             err = ("Either both or neither of `x` and `y` must be specified "
#     165                    "(but try passing to `data`, which is more flexible).")
# --> 166             raise ValueError(err)
#     167
#     168         # ---- Post-processing
#
# ValueError: Either both or neither of `x` and `y` must be specified (but try passing to `data`, which is more flexible).

# %%
ax = sns.countplot(x="Region", data=data[0:-1]);
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right");
pyplot.tight_layout();
pyplot.show();
##represents how many countires from different regions come to India

# %%
columns=temp_data_region['Region'];
columns
# Out:
# 0                 NORTH AMERICA
# 1     CENTRAL AND SOUTH AMERICA
# 2                WESTERN EUROPE
# 3                EASTERN EUROPE
# 4                        AFRICA
# 5                     WEST ASIA
# 6                    SOUTH ASIA
# 7               SOUTH EAST ASIA
# 8                     EAST ASIA
# 9                   AUSTRALASIA
# 10                    STATELESS
# 11                       Others
# Name: Region, dtype: object

# %%
temp_data_region
# Out:
#                        Region Nationality      2001      2002      2003  \
# 0               NORTH AMERICA       Total  417747.0  441780.0  518474.0
# 1   CENTRAL AND SOUTH AMERICA       Total   21925.0   17672.0   21654.0
# 2              WESTERN EUROPE       Total  819973.0  726783.0  847966.0
# 3              EASTERN EUROPE       Total   38863.0   40628.0   55252.0
# 4                      AFRICA       Total   90962.0   83457.0   93353.0
# 5                   WEST ASIA       Total   96424.0   92562.0  103596.0
# 6                  SOUTH ASIA       Total  672133.0  630653.0  666889.0
# 7             SOUTH EAST ASIA       Total  139975.0  149291.0  168926.0
# 8                   EAST ASIA       Total  130464.0  115424.0  150506.0
# 9                 AUSTRALASIA       Total   66104.0   63261.0   73849.0
# 10                  STATELESS       Total    9393.0   13487.0   15516.0
# 11                     Others       Total   33319.0    9366.0   10232.0
#
#          2004       2005       2006       2007       2008       2009  \
# 0    662004.0   768808.0   873306.0  1007276.0  1027297.0  1051209.0
# 1     28165.0    35586.0    38745.0    42319.0    43505.0    46604.0
# 2   1128297.0  1282119.0  1487271.0  1686083.0  1709525.0  1634042.0
# 3     82426.0   101445.0   121309.0   152764.0   191110.0   183475.0
# 4    115493.0   134801.0   142813.0   157485.0   141750.0   164474.0
# 5    122808.0   133821.0   146693.0   171661.0   215542.0   204843.0
# 6    790698.0   841969.0   908916.0   982428.0  1051846.0  1001401.0
# 7    209110.0   241408.0   281726.0   303475.0   332925.0   360191.0
# 8    201627.0   223567.0   282985.0   352037.0   355230.0   322797.0
# 9    100944.0   119778.0   137436.0   167063.0   178308.0   182451.0
# 10     1434.0    13490.0      647.0    26237.0     1025.0      624.0
# 11    13692.0    21818.0    25320.0    32676.0    34540.0    15588.0
#
#          2010       2011       2012       2013       2014       2015
# 0   1173664.0  1239705.0  1295968.0  1340531.0  1387468.0  1494930.0
# 1     62728.0    60988.0    63699.0    68436.0    69926.0    70831.0
# 2   1750342.0  1838695.0  1853066.0  1855866.0  1860580.0  1880203.0
# 3    227650.0   274598.0   312686.0   405083.0   422278.0   331051.0
# 4    204525.0   232386.0   261428.0   275271.0   280754.0   293569.0
# 5    235317.0   278773.0   290996.0   343113.0   413678.0   417616.0
# 6   1047444.0  1139659.0  1171499.0  1215035.0  1694857.0  1946207.0
# 7    439043.0   521755.0   540914.0   630054.0   685805.0   700298.0
# 8    411947.0   475951.0   535622.0   547305.0   546792.0   555770.0
# 9    210275.0   233165.0   244511.0   263574.0   286294.0   312101.0
# 10      670.0     1144.0     1426.0     1824.0     1879.0     2000.0
# 11    12087.0    12403.0     5930.0    21509.0    28788.0    22557.0

# %%
temp_data_region=temp_data_region.drop('Nationality', axis=1)

# %%
temp_data_region
# Out:
#                        Region      2001      2002      2003       2004  \
# 0               NORTH AMERICA  417747.0  441780.0  518474.0   662004.0
# 1   CENTRAL AND SOUTH AMERICA   21925.0   17672.0   21654.0    28165.0
# 2              WESTERN EUROPE  819973.0  726783.0  847966.0  1128297.0
# 3              EASTERN EUROPE   38863.0   40628.0   55252.0    82426.0
# 4                      AFRICA   90962.0   83457.0   93353.0   115493.0
# 5                   WEST ASIA   96424.0   92562.0  103596.0   122808.0
# 6                  SOUTH ASIA  672133.0  630653.0  666889.0   790698.0
# 7             SOUTH EAST ASIA  139975.0  149291.0  168926.0   209110.0
# 8                   EAST ASIA  130464.0  115424.0  150506.0   201627.0
# 9                 AUSTRALASIA   66104.0   63261.0   73849.0   100944.0
# 10                  STATELESS    9393.0   13487.0   15516.0     1434.0
# 11                     Others   33319.0    9366.0   10232.0    13692.0
#
#          2005       2006       2007       2008       2009       2010  \
# 0    768808.0   873306.0  1007276.0  1027297.0  1051209.0  1173664.0
# 1     35586.0    38745.0    42319.0    43505.0    46604.0    62728.0
# 2   1282119.0  1487271.0  1686083.0  1709525.0  1634042.0  1750342.0
# 3    101445.0   121309.0   152764.0   191110.0   183475.0   227650.0
# 4    134801.0   142813.0   157485.0   141750.0   164474.0   204525.0
# 5    133821.0   146693.0   171661.0   215542.0   204843.0   235317.0
# 6    841969.0   908916.0   982428.0  1051846.0  1001401.0  1047444.0
# 7    241408.0   281726.0   303475.0   332925.0   360191.0   439043.0
# 8    223567.0   282985.0   352037.0   355230.0   322797.0   411947.0
# 9    119778.0   137436.0   167063.0   178308.0   182451.0   210275.0
# 10    13490.0      647.0    26237.0     1025.0      624.0      670.0
# 11    21818.0    25320.0    32676.0    34540.0    15588.0    12087.0
#
#          2011       2012       2013       2014       2015
# 0   1239705.0  1295968.0  1340531.0  1387468.0  1494930.0
# 1     60988.0    63699.0    68436.0    69926.0    70831.0
# 2   1838695.0  1853066.0  1855866.0  1860580.0  1880203.0
# 3    274598.0   312686.0   405083.0   422278.0   331051.0
# 4    232386.0   261428.0   275271.0   280754.0   293569.0
# 5    278773.0   290996.0   343113.0   413678.0   417616.0
# 6   1139659.0  1171499.0  1215035.0  1694857.0  1946207.0
# 7    521755.0   540914.0   630054.0   685805.0   700298.0
# 8    475951.0   535622.0   547305.0   546792.0   555770.0
# 9    233165.0   244511.0   263574.0   286294.0   312101.0
# 10     1144.0     1426.0     1824.0     1879.0     2000.0
# 11    12403.0     5930.0    21509.0    28788.0    22557.0

# %%
# temp_data_region_top2001=temp_data_region.sort_values(by='2001', ascending=False);
# temp_data_region_bottom2001=temp+data_region

# %%
melted_region_data=pd.melt(temp_data_region, id_vars=['Region'], var_name='Year', value_name='FTA');

# %%
# melted_region_data=melted_region_data.groupby('Region');

# %%
melted_region_data
# Out:
#                         Region  Year        FTA
# 0                NORTH AMERICA  2001   417747.0
# 1    CENTRAL AND SOUTH AMERICA  2001    21925.0
# 2               WESTERN EUROPE  2001   819973.0
# 3               EASTERN EUROPE  2001    38863.0
# 4                       AFRICA  2001    90962.0
# 5                    WEST ASIA  2001    96424.0
# 6                   SOUTH ASIA  2001   672133.0
# 7              SOUTH EAST ASIA  2001   139975.0
# 8                    EAST ASIA  2001   130464.0
# 9                  AUSTRALASIA  2001    66104.0
# 10                   STATELESS  2001     9393.0
# 11                      Others  2001    33319.0
# 12               NORTH AMERICA  2002   441780.0
# 13   CENTRAL AND SOUTH AMERICA  2002    17672.0
# 14              WESTERN EUROPE  2002   726783.0
# 15              EASTERN EUROPE  2002    40628.0
# 16                      AFRICA  2002    83457.0
# 17                   WEST ASIA  2002    92562.0
# 18                  SOUTH ASIA  2002   630653.0
# 19             SOUTH EAST ASIA  2002   149291.0
# 20                   EAST ASIA  2002   115424.0
# 21                 AUSTRALASIA  2002    63261.0
# 22                   STATELESS  2002    13487.0
# 23                      Others  2002     9366.0
# 24               NORTH AMERICA  2003   518474.0
# 25   CENTRAL AND SOUTH AMERICA  2003    21654.0
# 26              WESTERN EUROPE  2003   847966.0
# 27              EASTERN EUROPE  2003    55252.0
# 28                      AFRICA  2003    93353.0
# 29                   WEST ASIA  2003   103596.0
# ..                         ...   ...        ...
# 150                 SOUTH ASIA  2013  1215035.0
# 151            SOUTH EAST ASIA  2013   630054.0
# 152                  EAST ASIA  2013   547305.0
# 153                AUSTRALASIA  2013   263574.0
# 154                  STATELESS  2013     1824.0
# 155                     Others  2013    21509.0
# 156              NORTH AMERICA  2014  1387468.0
# 157  CENTRAL AND SOUTH AMERICA  2014    69926.0
# 158             WESTERN EUROPE  2014  1860580.0
# 159             EASTERN EUROPE  2014   422278.0
# 160                     AFRICA  2014   280754.0
# 161                  WEST ASIA  2014   413678.0
# 162                 SOUTH ASIA  2014  1694857.0
# 163            SOUTH EAST ASIA  2014   685805.0
# 164                  EAST ASIA  2014   546792.0
# 165                AUSTRALASIA  2014   286294.0
# 166                  STATELESS  2014     1879.0
# 167                     Others  2014    28788.0
# 168              NORTH AMERICA  2015  1494930.0
# 169  CENTRAL AND SOUTH AMERICA  2015    70831.0
# 170             WESTERN EUROPE  2015  1880203.0
# 171             EASTERN EUROPE  2015   331051.0
# 172                     AFRICA  2015   293569.0
# 173                  WEST ASIA  2015   417616.0
# 174                 SOUTH ASIA  2015  1946207.0
# 175            SOUTH EAST ASIA  2015   700298.0
# 176                  EAST ASIA  2015   555770.0
# 177                AUSTRALASIA  2015   312101.0
# 178                  STATELESS  2015     2000.0
# 179                     Others  2015    22557.0
#
# [180 rows x 3 columns]

# %%
sns.relplot(data=melted_region_data, x='Year', y='FTA', kind='line');

# %%
temp2015=temp_data_region.sort_values(by='2015', ascending=False);
temp1=temp2015.iloc[:4];
temp1
# Out:
#             Region      2001      2002      2003       2004       2005  \
# 6       SOUTH ASIA  672133.0  630653.0  666889.0   790698.0   841969.0
# 2   WESTERN EUROPE  819973.0  726783.0  847966.0  1128297.0  1282119.0
# 0    NORTH AMERICA  417747.0  441780.0  518474.0   662004.0   768808.0
# 7  SOUTH EAST ASIA  139975.0  149291.0  168926.0   209110.0   241408.0
#
#         2006       2007       2008       2009       2010       2011  \
# 6   908916.0   982428.0  1051846.0  1001401.0  1047444.0  1139659.0
# 2  1487271.0  1686083.0  1709525.0  1634042.0  1750342.0  1838695.0
# 0   873306.0  1007276.0  1027297.0  1051209.0  1173664.0  1239705.0
# 7   281726.0   303475.0   332925.0   360191.0   439043.0   521755.0
#
#         2012       2013       2014       2015
# 6  1171499.0  1215035.0  1694857.0  1946207.0
# 2  1853066.0  1855866.0  1860580.0  1880203.0
# 0  1295968.0  1340531.0  1387468.0  1494930.0
# 7   540914.0   630054.0   685805.0   700298.0

# %%
temp2=temp2015.iloc[4:8]
temp2
# Out:
#            Region      2001      2002      2003      2004      2005      2006  \
# 8       EAST ASIA  130464.0  115424.0  150506.0  201627.0  223567.0  282985.0
# 5       WEST ASIA   96424.0   92562.0  103596.0  122808.0  133821.0  146693.0
# 3  EASTERN EUROPE   38863.0   40628.0   55252.0   82426.0  101445.0  121309.0
# 9     AUSTRALASIA   66104.0   63261.0   73849.0  100944.0  119778.0  137436.0
#
#        2007      2008      2009      2010      2011      2012      2013  \
# 8  352037.0  355230.0  322797.0  411947.0  475951.0  535622.0  547305.0
# 5  171661.0  215542.0  204843.0  235317.0  278773.0  290996.0  343113.0
# 3  152764.0  191110.0  183475.0  227650.0  274598.0  312686.0  405083.0
# 9  167063.0  178308.0  182451.0  210275.0  233165.0  244511.0  263574.0
#
#        2014      2015
# 8  546792.0  555770.0
# 5  413678.0  417616.0
# 3  422278.0  331051.0
# 9  286294.0  312101.0

# %%
temp3=temp2015.iloc[8:];
temp3
# Out:
#                        Region     2001     2002     2003      2004      2005  \
# 4                      AFRICA  90962.0  83457.0  93353.0  115493.0  134801.0
# 1   CENTRAL AND SOUTH AMERICA  21925.0  17672.0  21654.0   28165.0   35586.0
# 11                     Others  33319.0   9366.0  10232.0   13692.0   21818.0
# 10                  STATELESS   9393.0  13487.0  15516.0    1434.0   13490.0
#
#         2006      2007      2008      2009      2010      2011      2012  \
# 4   142813.0  157485.0  141750.0  164474.0  204525.0  232386.0  261428.0
# 1    38745.0   42319.0   43505.0   46604.0   62728.0   60988.0   63699.0
# 11   25320.0   32676.0   34540.0   15588.0   12087.0   12403.0    5930.0
# 10     647.0   26237.0    1025.0     624.0     670.0    1144.0    1426.0
#
#         2013      2014      2015
# 4   275271.0  280754.0  293569.0
# 1    68436.0   69926.0   70831.0
# 11   21509.0   28788.0   22557.0
# 10    1824.0    1879.0    2000.0

# %%
melted_temp1=pd.melt(temp1, id_vars=['Region'], var_name='Year', value_name='FTA');
melted_temp2=pd.melt(temp2, id_vars=['Region'], var_name='Year', value_name='FTA');
melted_temp3=pd.melt(temp3, id_vars=['Region'], var_name='Year', value_name='FTA');

# %%
melted_temp1.head(7)
# Out:
#             Region  Year       FTA
# 0       SOUTH ASIA  2001  672133.0
# 1   WESTERN EUROPE  2001  819973.0
# 2    NORTH AMERICA  2001  417747.0
# 3  SOUTH EAST ASIA  2001  139975.0
# 4       SOUTH ASIA  2002  630653.0
# 5   WESTERN EUROPE  2002  726783.0
# 6    NORTH AMERICA  2002  441780.0

# %%
pyplot.style.use('ggplot');

a1=sns.relplot(x="Year", y="FTA", data=melted_temp1, kind='line', style='Region', hue='Region', markers=True, dashes=False);
a1.fig.suptitle("FTA to India 2001-2015", y=1.05)
a1.set(xlabel='Years', ylabel='FTA');
# sns.set_context('notebook');
pyplot.xticks(rotation=450);
pyplot.show();
pyplot.clf();

# %%
pyplot.style.use('ggplot');

a1=sns.relplot(x="Year", y="FTA", data=melted_temp2, kind='line', style='Region', hue='Region', markers=True, dashes=False);
a1.fig.suptitle("FTA to India 2001-2015", y=1.05)
a1.set(xlabel='Years', ylabel='FTA');
# sns.set_context('notebook');
pyplot.xticks(rotation=450);
pyplot.show();
pyplot.clf();

# %%
pyplot.style.use('ggplot');

a1=sns.relplot(x="Year", y="FTA", data=melted_temp3, kind='line', style='Region', hue='Region', markers=True, dashes=False);
a1.fig.suptitle("FTA to India 2001-2015", y=1.05)
a1.set(xlabel='Years', ylabel='FTA');
# sns.set_context('notebook');
pyplot.xticks(rotation=450);
pyplot.show();
pyplot.clf();
